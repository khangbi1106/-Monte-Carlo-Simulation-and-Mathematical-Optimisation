# %%
# !pip install numpy pandas gurobipy
# Out:
# Requirement already satisfied: numpy in c:\users\lenovo\anaconda3\lib\site-packages (1.26.4)
# Requirement already satisfied: pandas in c:\users\lenovo\anaconda3\lib\site-packages (2.2.2)
# Requirement already satisfied: gurobipy in c:\users\lenovo\anaconda3\lib\site-packages (12.0.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\lenovo\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\lenovo\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\lenovo\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\lenovo\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
# === Setup ===
import numpy as np
import pandas as pd
from gurobipy import Model, GRB, quicksum

# Fix random seed
np.random.seed(42)

# === Data ===

# Specialist time distributions
specialists = {
    'S1': (7.3, 1.0), 'S2': (4.0, 0.6), 'S3': (6.0, 1.2), 'S4': (7.5, 1.5),
    'S5': (5.0, 0.8), 'S6': (6.8, 1.3), 'S7': (3.5, 1.0), 'S8': (7.0, 1.1),
    'S9': (6.5, 1.0), 'S10': (5.5, 1.4)
}

# Room cost data
rooms = {
    'O1': {'regular_cost': 33, 'overtime_cost': 50},
    'O2': {'regular_cost': 28, 'overtime_cost': 45},
    'O3': {'regular_cost': 35, 'overtime_cost': 52},
    'O4': {'regular_cost': 30, 'overtime_cost': 47}
}

REGULAR_TIME = 12
NUM_DAYS = 500
room_names = list(rooms.keys())
specialist_names = list(specialists.keys())

# === Simulate 500 Days of Specialist Time ===
def simulate_days():
    data = {}
    for s, (mean, std) in specialists.items():
        data[s] = np.maximum(np.random.normal(loc=mean, scale=std, size=NUM_DAYS), 0)
    return pd.DataFrame(data)

sim_data = simulate_days()

# === MILP Solver for One Day ===
def solve_day(specialist_times, max_overtime):
    model = Model("OR_Scheduling")
    model.setParam('OutputFlag', 0)  # silence output

    x = model.addVars(specialist_names, room_names, vtype=GRB.BINARY, name="x")
    overtime = model.addVars(room_names, vtype=GRB.CONTINUOUS, lb=0, name="overtime")

    # Objective
    model.setObjective(
        quicksum(rooms[r]['regular_cost'] for r in room_names) +
        quicksum(overtime[r] * rooms[r]['overtime_cost'] for r in room_names),
        GRB.MINIMIZE
    )

    # Constraints
    for s in specialist_names:
        model.addConstr(quicksum(x[s, r] for r in room_names) == 1)

    for r in room_names:
        model.addConstr(quicksum(x[s, r] for s in specialist_names) <= 3)

    # Equipment conflicts
    for r in room_names:
        model.addConstr(x['S2', r] + x['S7', r] <= 1)
        model.addConstr(x['S4', r] + x['S5', r] <= 1)

    for r in room_names:
        total_time = quicksum(specialist_times[s] * x[s, r] for s in specialist_names)
        model.addConstr(total_time <= REGULAR_TIME + overtime[r])
        model.addConstr(overtime[r] <= max_overtime)

    model.optimize()

    if model.status == GRB.OPTIMAL:
        total_cost = model.objVal
        overtime_usage = {r: overtime[r].X for r in room_names}
        return total_cost, overtime_usage
    else:
        return None, None

# === Run Simulation for Each Policy ===
def evaluate_policy(max_overtime):
    daily_costs = []
    daily_overtimes = {r: [] for r in room_names}

    for day in range(NUM_DAYS):
        specialist_times = sim_data.iloc[day].to_dict()
        cost, ot = solve_day(specialist_times, max_overtime)
        if cost is not None:
            daily_costs.append(cost)
            for r in room_names:
                daily_overtimes[r].append(ot[r])
        else:
            print(f"Day {day} failed to solve.")

    return daily_costs, pd.DataFrame(daily_overtimes)

# === Run all three policies ===
policies = {
    "Policy 1 (3h)": 3,
    "Policy 2 (5h)": 5,
    "Policy 3 (7h)": 7
}

results = {}

for name, limit in policies.items():
    print(f"Running {name}...")
    costs, overtimes = evaluate_policy(limit)
    results[name] = {
        "costs": costs,
        "overtimes": overtimes,
        "mean_cost": np.mean(costs),
        "max_ot": overtimes.max(),
        "mean_ot": overtimes.mean()
    }

# === Show Results Summary ===
for name in policies:
    print(f"\n{name}:")
    print(f"  Average Cost: {results[name]['mean_cost']:.2f}")
    print(f"  Max Overtime Per Room:\n{results[name]['max_ot']}")
    print(f"  Mean Overtime Per Room:\n{results[name]['mean_ot']}")
# Out:
# Running Policy 1 (3h)...
# Set parameter Username
# Set parameter LicenseID to value 2634663
# Academic license - for non-commercial use only - expires 2026-03-10
# Day 0 failed to solve.
# Day 1 failed to solve.
# Day 3 failed to solve.
# Day 6 failed to solve.
# Day 7 failed to solve.
# Day 8 failed to solve.
# Day 11 failed to solve.
# Day 12 failed to solve.
# Day 15 failed to solve.
# Day 18 failed to solve.
# Day 20 failed to solve.
# Day 21 failed to solve.
# Day 23 failed to solve.
# Day 25 failed to solve.
# Day 26 failed to solve.
# Day 27 failed to solve.
# Day 28 failed to solve.
# Day 30 failed to solve.
# Day 32 failed to solve.
# Day 34 failed to solve.
# Day 35 failed to solve.
# Day 36 failed to solve.
# Day 40 failed to solve.
# Day 41 failed to solve.
# Day 43 failed to solve.
# Day 44 failed to solve.
# Day 45 failed to solve.
# Day 46 failed to solve.
# Day 47 failed to solve.
# Day 48 failed to solve.
# Day 49 failed to solve.
# Day 52 failed to solve.
# Day 53 failed to solve.
# Day 55 failed to solve.
# Day 57 failed to solve.
# Day 58 failed to solve.
# Day 59 failed to solve.
# Day 64 failed to solve.
# Day 67 failed to solve.
# Day 68 failed to solve.
# Day 69 failed to solve.
# Day 70 failed to solve.
# Day 71 failed to solve.
# Day 72 failed to solve.
# Day 75 failed to solve.
# Day 77 failed to solve.
# Day 79 failed to solve.
# Day 80 failed to solve.
# Day 81 failed to solve.
# Day 82 failed to solve.
# Day 83 failed to solve.
# Day 84 failed to solve.
# Day 85 failed to solve.
# Day 86 failed to solve.
# Day 87 failed to solve.
# Day 89 failed to solve.
# Day 91 failed to solve.
# Day 92 failed to solve.
# Day 94 failed to solve.
# Day 96 failed to solve.
# Day 97 failed to solve.
# Day 98 failed to solve.
# Day 99 failed to solve.
# Day 102 failed to solve.
# Day 103 failed to solve.
# Day 105 failed to solve.
# Day 107 failed to solve.
# Day 108 failed to solve.
# Day 109 failed to solve.
# Day 112 failed to solve.
# Day 114 failed to solve.
# Day 115 failed to solve.
# Day 116 failed to solve.
# Day 118 failed to solve.
# Day 119 failed to solve.
# Day 120 failed to solve.
# Day 121 failed to solve.
# Day 122 failed to solve.
# Day 123 failed to solve.
# Day 124 failed to solve.
# Day 125 failed to solve.
# Day 127 failed to solve.
# Day 128 failed to solve.
# Day 129 failed to solve.
# Day 131 failed to solve.
# Day 132 failed to solve.
# Day 133 failed to solve.
# Day 136 failed to solve.
# Day 140 failed to solve.
# Day 141 failed to solve.
# Day 143 failed to solve.
# Day 145 failed to solve.
# Day 148 failed to solve.
# Day 149 failed to solve.
# Day 150 failed to solve.
# Day 151 failed to solve.
# Day 154 failed to solve.
# Day 155 failed to solve.
# Day 157 failed to solve.
# Day 158 failed to solve.
# Day 159 failed to solve.
# Day 161 failed to solve.
# Day 164 failed to solve.
# Day 166 failed to solve.
# Day 167 failed to solve.
# Day 168 failed to solve.
# Day 169 failed to solve.
# Day 170 failed to solve.
# Day 174 failed to solve.
# Day 177 failed to solve.
# Day 178 failed to solve.
# Day 179 failed to solve.
# Day 180 failed to solve.
# Day 183 failed to solve.
# Day 185 failed to solve.
# Day 186 failed to solve.
# Day 188 failed to solve.
# Day 189 failed to solve.
# Day 191 failed to solve.
# Day 192 failed to solve.
# Day 195 failed to solve.
# Day 196 failed to solve.
# Day 199 failed to solve.
# Day 200 failed to solve.
# Day 201 failed to solve.
# Day 202 failed to solve.
# Day 203 failed to solve.
# Day 205 failed to solve.
# Day 206 failed to solve.
# Day 207 failed to solve.
# Day 209 failed to solve.
# Day 212 failed to solve.
# Day 213 failed to solve.
# Day 214 failed to solve.
# Day 215 failed to solve.
# Day 216 failed to solve.
# Day 217 failed to solve.
# Day 218 failed to solve.
# Day 219 failed to solve.
# Day 220 failed to solve.
# Day 221 failed to solve.
# Day 222 failed to solve.
# Day 223 failed to solve.
# Day 225 failed to solve.
# Day 226 failed to solve.
# Day 227 failed to solve.
# Day 228 failed to solve.
# Day 229 failed to solve.
# Day 233 failed to solve.
# Day 234 failed to solve.
# Day 235 failed to solve.
# Day 238 failed to solve.
# Day 239 failed to solve.
# Day 241 failed to solve.
# Day 243 failed to solve.
# Day 248 failed to solve.
# Day 250 failed to solve.
# Day 251 failed to solve.
# Day 255 failed to solve.
# Day 256 failed to solve.
# Day 257 failed to solve.
# Day 259 failed to solve.
# Day 260 failed to solve.
# Day 261 failed to solve.
# Day 262 failed to solve.
# Day 264 failed to solve.
# Day 265 failed to solve.
# Day 266 failed to solve.
# Day 269 failed to solve.
# Day 270 failed to solve.
# Day 275 failed to solve.
# Day 276 failed to solve.
# Day 279 failed to solve.
# Day 280 failed to solve.
# Day 284 failed to solve.
# Day 285 failed to solve.
# Day 289 failed to solve.
# Day 290 failed to solve.
# Day 291 failed to solve.
# Day 292 failed to solve.
# Day 293 failed to solve.
# Day 296 failed to solve.
# Day 299 failed to solve.
# Day 300 failed to solve.
# Day 306 failed to solve.
# Day 308 failed to solve.
# Day 309 failed to solve.
# Day 312 failed to solve.
# Day 313 failed to solve.
# Day 314 failed to solve.
# Day 318 failed to solve.
# Day 320 failed to solve.
# Day 321 failed to solve.
# Day 322 failed to solve.
# Day 323 failed to solve.
# Day 324 failed to solve.
# Day 325 failed to solve.
# Day 327 failed to solve.
# Day 328 failed to solve.
# Day 329 failed to solve.
# Day 330 failed to solve.
# Day 332 failed to solve.
# Day 333 failed to solve.
# Day 334 failed to solve.
# Day 335 failed to solve.
# Day 337 failed to solve.
# Day 338 failed to solve.
# Day 339 failed to solve.
# Day 340 failed to solve.
# Day 342 failed to solve.
# Day 344 failed to solve.
# Day 345 failed to solve.
# Day 347 failed to solve.
# Day 351 failed to solve.
# Day 352 failed to solve.
# Day 353 failed to solve.
# Day 354 failed to solve.
# Day 357 failed to solve.
# Day 358 failed to solve.
# Day 359 failed to solve.
# Day 364 failed to solve.
# Day 367 failed to solve.
# Day 368 failed to solve.
# Day 369 failed to solve.
# Day 371 failed to solve.
# Day 374 failed to solve.
# Day 375 failed to solve.
# Day 377 failed to solve.
# Day 379 failed to solve.
# Day 380 failed to solve.
# Day 381 failed to solve.
# Day 383 failed to solve.
# Day 384 failed to solve.
# Day 385 failed to solve.
# Day 387 failed to solve.
# Day 388 failed to solve.
# Day 389 failed to solve.
# Day 393 failed to solve.
# Day 394 failed to solve.
# Day 395 failed to solve.
# Day 397 failed to solve.
# Day 398 failed to solve.
# Day 399 failed to solve.
# Day 401 failed to solve.
# Day 402 failed to solve.
# Day 403 failed to solve.
# Day 404 failed to solve.
# Day 405 failed to solve.
# Day 408 failed to solve.
# Day 409 failed to solve.
# Day 410 failed to solve.
# Day 411 failed to solve.
# Day 412 failed to solve.
# Day 413 failed to solve.
# Day 415 failed to solve.
# Day 416 failed to solve.
# Day 417 failed to solve.
# Day 418 failed to solve.
# Day 419 failed to solve.
# Day 420 failed to solve.
# Day 421 failed to solve.
# Day 422 failed to solve.
# Day 423 failed to solve.
# Day 424 failed to solve.
# Day 427 failed to solve.
# Day 428 failed to solve.
# Day 429 failed to solve.
# Day 430 failed to solve.
# Day 432 failed to solve.
# Day 433 failed to solve.
# Day 434 failed to solve.
# Day 435 failed to solve.
# Day 436 failed to solve.
# Day 437 failed to solve.
# Day 440 failed to solve.
# Day 441 failed to solve.
# Day 444 failed to solve.
# Day 446 failed to solve.
# Day 448 failed to solve.
# Day 451 failed to solve.
# Day 452 failed to solve.
# Day 453 failed to solve.
# Day 454 failed to solve.
# Day 455 failed to solve.
# Day 457 failed to solve.
# Day 458 failed to solve.
# Day 459 failed to solve.
# Day 460 failed to solve.
# Day 461 failed to solve.
# Day 462 failed to solve.
# Day 463 failed to solve.
# Day 464 failed to solve.
# Day 465 failed to solve.
# Day 466 failed to solve.
# Day 467 failed to solve.
# Day 469 failed to solve.
# Day 470 failed to solve.
# Day 472 failed to solve.
# Day 474 failed to solve.
# Day 476 failed to solve.
# Day 477 failed to solve.
# Day 478 failed to solve.
# Day 479 failed to solve.
# Day 481 failed to solve.
# Day 482 failed to solve.
# Day 484 failed to solve.
# Day 486 failed to solve.
# Day 489 failed to solve.
# Day 491 failed to solve.
# Day 493 failed to solve.
# Day 494 failed to solve.
# Day 495 failed to solve.
# Day 496 failed to solve.
# Day 497 failed to solve.
# Day 498 failed to solve.
# Running Policy 2 (5h)...
# Day 6 failed to solve.
# Day 27 failed to solve.
# Day 102 failed to solve.
# Day 114 failed to solve.
# Day 115 failed to solve.
# Day 124 failed to solve.
# Day 133 failed to solve.
# Day 178 failed to solve.
# Day 185 failed to solve.
# Day 192 failed to solve.
# Day 239 failed to solve.
# Day 241 failed to solve.
# Day 269 failed to solve.
# Day 308 failed to solve.
# Day 312 failed to solve.
# Day 398 failed to solve.
# Day 411 failed to solve.
# Day 434 failed to solve.
# Day 495 failed to solve.
# Running Policy 3 (7h)...
#
# Policy 1 (3h):
#   Average Cost: 501.68
#   Max Overtime Per Room:
# O1    2.909914
# O2    3.000002
# O3    2.754030
# O4    2.994947
# dtype: float64
#   Mean Overtime Per Room:
# O1    1.758681
# O2    2.836898
# O3    0.787195
# O4    2.535058
# dtype: float64
#
# Policy 2 (5h):
#   Average Cost: 636.60
#   Max Overtime Per Room:
# O1    4.905374
# O2    4.999934
# O3    3.994050
# O4    4.995636
# dtype: float64
#   Mean Overtime Per Room:
# O1    1.766143
# O2    4.750632
# O3    0.457636
# O4    3.930239
# dtype: float64
#
# Policy 3 (7h):
#   Average Cost: 642.04
#   Max Overtime Per Room:
# O1    6.895520
# O2    6.999940
# O3    2.043456
# O4    6.976372
# dtype: float64
#   Mean Overtime Per Room:
# O1    0.720283
# O2    6.450917
# O3    0.142244
# O4    3.879519
# dtype: float64

# %%
def solve_day_with_scenario(specialist_times, max_overtime, scenario=None, fixed_room=None):
    model = Model("OR_Scheduling_Scenario")
    model.setParam('OutputFlag', 0)

    x = model.addVars(specialist_names, room_names, vtype=GRB.BINARY, name="x")
    overtime = model.addVars(room_names, vtype=GRB.CONTINUOUS, lb=0, name="overtime")

    # Objective function
    model.setObjective(
        quicksum(rooms[r]['regular_cost'] for r in room_names) +
        quicksum(overtime[r] * rooms[r]['overtime_cost'] for r in room_names),
        GRB.MINIMIZE
    )

    # Basic constraints
    for s in specialist_names:
        model.addConstr(quicksum(x[s, r] for r in room_names) == 1)

    for r in room_names:
        model.addConstr(quicksum(x[s, r] for s in specialist_names) <= 3)

    # Equipment conflicts
    for r in room_names:
        model.addConstr(x['S2', r] + x['S7', r] <= 1)
        model.addConstr(x['S4', r] + x['S5', r] <= 1)

    for r in room_names:
        total_time = quicksum(specialist_times[s] * x[s, r] for s in specialist_names)
        model.addConstr(total_time <= REGULAR_TIME + overtime[r])
        model.addConstr(overtime[r] <= max_overtime)

    # Scenario-specific constraints
    if scenario == 1:
        model.addConstr(overtime['O3'] == 0)
    elif scenario == 2:
        model.addConstr(x['S4', 'O1'] == 0)
        model.addConstr(x['S4', 'O2'] == 0)
    elif scenario == 3:
        if fixed_room is not None:
            for r in room_names:
                if r != fixed_room:
                    model.addConstr(x['S4', r] == 0)

    model.optimize()

    if model.status == GRB.OPTIMAL:
        total_cost = model.objVal
        overtime_usage = {r: overtime[r].X for r in room_names}
        s4_room = [r for r in room_names if x['S4', r].X > 0.5][0]
        return total_cost, overtime_usage, s4_room
    else:
        return None, None, None

# %%
def evaluate_scenario(policy_limit, scenario=None, fixed_room=None):
    daily_costs = []
    daily_overtimes = {r: [] for r in room_names}
    s4_rooms = []

    for day in range(NUM_DAYS):
        specialist_times = sim_data.iloc[day].to_dict()
        cost, ot, s4_room = solve_day_with_scenario(specialist_times, policy_limit, scenario, fixed_room)
        if cost is not None:
            daily_costs.append(cost)
            for r in room_names:
                daily_overtimes[r].append(ot[r])
            s4_rooms.append(s4_room)
        else:
            print(f"Day {day} failed.")

    return daily_costs, pd.DataFrame(daily_overtimes), s4_rooms

# %%
best_policy = min(results.items(), key=lambda x: x[1]["mean_cost"])
print(f"\n✅ Best policy is: {best_policy[0]} with average cost = {best_policy[1]['mean_cost']:.2f}")
BEST_POLICY_LIMIT = policies[best_policy[0]]  # Use for Part B
# Out:
# ✅ Best policy is: Policy 1 (3h) with average cost = 501.68

# %%
# Policy 1 (3h) was the best. 
BEST_POLICY_LIMIT = 3

# Scenario 1: No overtime for O3
costs1, ot1, _ = evaluate_scenario(BEST_POLICY_LIMIT, scenario=1)
print(f"Scenario 1 - Avg Cost: {np.mean(costs1):.2f}")

# Scenario 2: S4 can only be in OR3 or OR4
costs2, ot2, _ = evaluate_scenario(BEST_POLICY_LIMIT, scenario=2)
print(f"Scenario 2 - Avg Cost: {np.mean(costs2):.2f}")

# Scenario 3: S4 must stay in same room daily
_, _, s4_base_rooms = evaluate_scenario(BEST_POLICY_LIMIT)  # get baseline S4 room
from collections import Counter
most_common_room = Counter(s4_base_rooms).most_common(1)[0][0]

costs3, ot3, _ = evaluate_scenario(BEST_POLICY_LIMIT, scenario=3, fixed_room=most_common_room)
print(f"Scenario 3 - Avg Cost: {np.mean(costs3):.2f}")
# Out:
# Day 0 failed.
# Day 1 failed.
# Day 2 failed.
# Day 3 failed.
# Day 6 failed.
# Day 7 failed.
# Day 8 failed.
# Day 9 failed.
# Day 10 failed.
# Day 11 failed.
# Day 12 failed.
# Day 14 failed.
# Day 15 failed.
# Day 16 failed.
# Day 18 failed.
# Day 20 failed.
# Day 21 failed.
# Day 22 failed.
# Day 23 failed.
# Day 24 failed.
# Day 25 failed.
# Day 26 failed.
# Day 27 failed.
# Day 28 failed.
# Day 30 failed.
# Day 32 failed.
# Day 34 failed.
# Day 35 failed.
# Day 36 failed.
# Day 39 failed.
# Day 40 failed.
# Day 41 failed.
# Day 42 failed.
# Day 43 failed.
# Day 44 failed.
# Day 45 failed.
# Day 46 failed.
# Day 47 failed.
# Day 48 failed.
# Day 49 failed.
# Day 50 failed.
# Day 52 failed.
# Day 53 failed.
# Day 54 failed.
# Day 55 failed.
# Day 57 failed.
# Day 58 failed.
# Day 59 failed.
# Day 60 failed.
# Day 61 failed.
# Day 63 failed.
# Day 64 failed.
# Day 65 failed.
# Day 67 failed.
# Day 68 failed.
# Day 69 failed.
# Day 70 failed.
# Day 71 failed.
# Day 72 failed.
# Day 73 failed.
# Day 74 failed.
# Day 75 failed.
# Day 76 failed.
# Day 77 failed.
# Day 78 failed.
# Day 79 failed.
# Day 80 failed.
# Day 81 failed.
# Day 82 failed.
# Day 83 failed.
# Day 84 failed.
# Day 85 failed.
# Day 86 failed.
# Day 87 failed.
# Day 89 failed.
# Day 90 failed.
# Day 91 failed.
# Day 92 failed.
# Day 94 failed.
# Day 96 failed.
# Day 97 failed.
# Day 98 failed.
# Day 99 failed.
# Day 101 failed.
# Day 102 failed.
# Day 103 failed.
# Day 104 failed.
# Day 105 failed.
# Day 106 failed.
# Day 107 failed.
# Day 108 failed.
# Day 109 failed.
# Day 110 failed.
# Day 112 failed.
# Day 113 failed.
# Day 114 failed.
# Day 115 failed.
# Day 116 failed.
# Day 118 failed.
# Day 119 failed.
# Day 120 failed.
# Day 121 failed.
# Day 122 failed.
# Day 123 failed.
# Day 124 failed.
# Day 125 failed.
# Day 127 failed.
# Day 128 failed.
# Day 129 failed.
# Day 131 failed.
# Day 132 failed.
# Day 133 failed.
# Day 134 failed.
# Day 135 failed.
# Day 136 failed.
# Day 137 failed.
# Day 138 failed.
# Day 140 failed.
# Day 141 failed.
# Day 143 failed.
# Day 145 failed.
# Day 148 failed.
# Day 149 failed.
# Day 150 failed.
# Day 151 failed.
# Day 153 failed.
# Day 154 failed.
# Day 155 failed.
# Day 156 failed.
# Day 157 failed.
# Day 158 failed.
# Day 159 failed.
# Day 160 failed.
# Day 161 failed.
# Day 164 failed.
# Day 165 failed.
# Day 166 failed.
# Day 167 failed.
# Day 168 failed.
# Day 169 failed.
# Day 170 failed.
# Day 171 failed.
# Day 172 failed.
# Day 173 failed.
# Day 174 failed.
# Day 175 failed.
# Day 176 failed.
# Day 177 failed.
# Day 178 failed.
# Day 179 failed.
# Day 180 failed.
# Day 181 failed.
# Day 182 failed.
# Day 183 failed.
# Day 185 failed.
# Day 186 failed.
# Day 188 failed.
# Day 189 failed.
# Day 190 failed.
# Day 191 failed.
# Day 192 failed.
# Day 195 failed.
# Day 196 failed.
# Day 198 failed.
# Day 199 failed.
# Day 200 failed.
# Day 201 failed.
# Day 202 failed.
# Day 203 failed.
# Day 204 failed.
# Day 205 failed.
# Day 206 failed.
# Day 207 failed.
# Day 208 failed.
# Day 209 failed.
# Day 211 failed.
# Day 212 failed.
# Day 213 failed.
# Day 214 failed.
# Day 215 failed.
# Day 216 failed.
# Day 217 failed.
# Day 218 failed.
# Day 219 failed.
# Day 220 failed.
# Day 221 failed.
# Day 222 failed.
# Day 223 failed.
# Day 224 failed.
# Day 225 failed.
# Day 226 failed.
# Day 227 failed.
# Day 228 failed.
# Day 229 failed.
# Day 231 failed.
# Day 233 failed.
# Day 234 failed.
# Day 235 failed.
# Day 236 failed.
# Day 238 failed.
# Day 239 failed.
# Day 241 failed.
# Day 242 failed.
# Day 243 failed.
# Day 244 failed.
# Day 246 failed.
# Day 248 failed.
# Day 250 failed.
# Day 251 failed.
# Day 252 failed.
# Day 253 failed.
# Day 254 failed.
# Day 255 failed.
# Day 256 failed.
# Day 257 failed.
# Day 258 failed.
# Day 259 failed.
# Day 260 failed.
# Day 261 failed.
# Day 262 failed.
# Day 264 failed.
# Day 265 failed.
# Day 266 failed.
# Day 267 failed.
# Day 268 failed.
# Day 269 failed.
# Day 270 failed.
# Day 271 failed.
# Day 272 failed.
# Day 273 failed.
# Day 275 failed.
# Day 276 failed.
# Day 277 failed.
# Day 279 failed.
# Day 280 failed.
# Day 281 failed.
# Day 283 failed.
# Day 284 failed.
# Day 285 failed.
# Day 286 failed.
# Day 289 failed.
# Day 290 failed.
# Day 291 failed.
# Day 292 failed.
# Day 293 failed.
# Day 294 failed.
# Day 296 failed.
# Day 299 failed.
# Day 300 failed.
# Day 301 failed.
# Day 304 failed.
# Day 306 failed.
# Day 307 failed.
# Day 308 failed.
# Day 309 failed.
# Day 310 failed.
# Day 311 failed.
# Day 312 failed.
# Day 313 failed.
# Day 314 failed.
# Day 316 failed.
# Day 317 failed.
# Day 318 failed.
# Day 320 failed.
# Day 321 failed.
# Day 322 failed.
# Day 323 failed.
# Day 324 failed.
# Day 325 failed.
# Day 326 failed.
# Day 327 failed.
# Day 328 failed.
# Day 329 failed.
# Day 330 failed.
# Day 332 failed.
# Day 333 failed.
# Day 334 failed.
# Day 335 failed.
# Day 336 failed.
# Day 337 failed.
# Day 338 failed.
# Day 339 failed.
# Day 340 failed.
# Day 342 failed.
# Day 343 failed.
# Day 344 failed.
# Day 345 failed.
# Day 347 failed.
# Day 348 failed.
# Day 349 failed.
# Day 351 failed.
# Day 352 failed.
# Day 353 failed.
# Day 354 failed.
# Day 355 failed.
# Day 356 failed.
# Day 357 failed.
# Day 358 failed.
# Day 359 failed.
# Day 362 failed.
# Day 363 failed.
# Day 364 failed.
# Day 365 failed.
# Day 366 failed.
# Day 367 failed.
# Day 368 failed.
# Day 369 failed.
# Day 370 failed.
# Day 371 failed.
# Day 373 failed.
# Day 374 failed.
# Day 375 failed.
# Day 377 failed.
# Day 378 failed.
# Day 379 failed.
# Day 380 failed.
# Day 381 failed.
# Day 383 failed.
# Day 384 failed.
# Day 385 failed.
# Day 387 failed.
# Day 388 failed.
# Day 389 failed.
# Day 390 failed.
# Day 392 failed.
# Day 393 failed.
# Day 394 failed.
# Day 395 failed.
# Day 397 failed.
# Day 398 failed.
# Day 399 failed.
# Day 400 failed.
# Day 401 failed.
# Day 402 failed.
# Day 403 failed.
# Day 404 failed.
# Day 405 failed.
# Day 408 failed.
# Day 409 failed.
# Day 410 failed.
# Day 411 failed.
# Day 412 failed.
# Day 413 failed.
# Day 415 failed.
# Day 416 failed.
# Day 417 failed.
# Day 418 failed.
# Day 419 failed.
# Day 420 failed.
# Day 421 failed.
# Day 422 failed.
# Day 423 failed.
# Day 424 failed.
# Day 426 failed.
# Day 427 failed.
# Day 428 failed.
# Day 429 failed.
# Day 430 failed.
# Day 432 failed.
# Day 433 failed.
# Day 434 failed.
# Day 435 failed.
# Day 436 failed.
# Day 437 failed.
# Day 438 failed.
# Day 439 failed.
# Day 440 failed.
# Day 441 failed.
# Day 442 failed.
# Day 443 failed.
# Day 444 failed.
# Day 445 failed.
# Day 446 failed.
# Day 448 failed.
# Day 449 failed.
# Day 450 failed.
# Day 451 failed.
# Day 452 failed.
# Day 453 failed.
# Day 454 failed.
# Day 455 failed.
# Day 456 failed.
# Day 457 failed.
# Day 458 failed.
# Day 459 failed.
# Day 460 failed.
# Day 461 failed.
# Day 462 failed.
# Day 463 failed.
# Day 464 failed.
# Day 465 failed.
# Day 466 failed.
# Day 467 failed.
# Day 468 failed.
# Day 469 failed.
# Day 470 failed.
# Day 472 failed.
# Day 473 failed.
# Day 474 failed.
# Day 475 failed.
# Day 476 failed.
# Day 477 failed.
# Day 478 failed.
# Day 479 failed.
# Day 480 failed.
# Day 481 failed.
# Day 482 failed.
# Day 483 failed.
# Day 484 failed.
# Day 485 failed.
# Day 486 failed.
# Day 487 failed.
# Day 488 failed.
# Day 489 failed.
# Day 490 failed.
# Day 491 failed.
# Day 492 failed.
# Day 493 failed.
# Day 494 failed.
# Day 495 failed.
# Day 496 failed.
# Day 497 failed.
# Day 498 failed.
# Scenario 1 - Avg Cost: 415.56
# Day 0 failed.
# Day 1 failed.
# Day 3 failed.
# Day 6 failed.
# Day 7 failed.
# Day 8 failed.
# Day 11 failed.
# Day 12 failed.
# Day 15 failed.
# Day 18 failed.
# Day 20 failed.
# Day 21 failed.
# Day 23 failed.
# Day 25 failed.
# Day 26 failed.
# Day 27 failed.
# Day 28 failed.
# Day 30 failed.
# Day 32 failed.
# Day 34 failed.
# Day 35 failed.
# Day 36 failed.
# Day 40 failed.
# Day 41 failed.
# Day 43 failed.
# Day 44 failed.
# Day 45 failed.
# Day 46 failed.
# Day 47 failed.
# Day 48 failed.
# Day 49 failed.
# Day 52 failed.
# Day 53 failed.
# Day 55 failed.
# Day 57 failed.
# Day 58 failed.
# Day 59 failed.
# Day 64 failed.
# Day 67 failed.
# Day 68 failed.
# Day 69 failed.
# Day 70 failed.
# Day 71 failed.
# Day 72 failed.
# Day 75 failed.
# Day 77 failed.
# Day 79 failed.
# Day 80 failed.
# Day 81 failed.
# Day 82 failed.
# Day 83 failed.
# Day 84 failed.
# Day 85 failed.
# Day 86 failed.
# Day 87 failed.
# Day 89 failed.
# Day 91 failed.
# Day 92 failed.
# Day 94 failed.
# Day 96 failed.
# Day 97 failed.
# Day 98 failed.
# Day 99 failed.
# Day 102 failed.
# Day 103 failed.
# Day 105 failed.
# Day 107 failed.
# Day 108 failed.
# Day 109 failed.
# Day 112 failed.
# Day 114 failed.
# Day 115 failed.
# Day 116 failed.
# Day 118 failed.
# Day 119 failed.
# Day 120 failed.
# Day 121 failed.
# Day 122 failed.
# Day 123 failed.
# Day 124 failed.
# Day 125 failed.
# Day 127 failed.
# Day 128 failed.
# Day 129 failed.
# Day 131 failed.
# Day 132 failed.
# Day 133 failed.
# Day 136 failed.
# Day 140 failed.
# Day 141 failed.
# Day 143 failed.
# Day 145 failed.
# Day 148 failed.
# Day 149 failed.
# Day 150 failed.
# Day 151 failed.
# Day 154 failed.
# Day 155 failed.
# Day 157 failed.
# Day 158 failed.
# Day 159 failed.
# Day 161 failed.
# Day 164 failed.
# Day 166 failed.
# Day 167 failed.
# Day 168 failed.
# Day 169 failed.
# Day 170 failed.
# Day 174 failed.
# Day 177 failed.
# Day 178 failed.
# Day 179 failed.
# Day 180 failed.
# Day 183 failed.
# Day 185 failed.
# Day 186 failed.
# Day 188 failed.
# Day 189 failed.
# Day 191 failed.
# Day 192 failed.
# Day 195 failed.
# Day 196 failed.
# Day 199 failed.
# Day 200 failed.
# Day 201 failed.
# Day 202 failed.
# Day 203 failed.
# Day 205 failed.
# Day 206 failed.
# Day 207 failed.
# Day 209 failed.
# Day 212 failed.
# Day 213 failed.
# Day 214 failed.
# Day 215 failed.
# Day 216 failed.
# Day 217 failed.
# Day 218 failed.
# Day 219 failed.
# Day 220 failed.
# Day 221 failed.
# Day 222 failed.
# Day 223 failed.
# Day 225 failed.
# Day 226 failed.
# Day 227 failed.
# Day 228 failed.
# Day 229 failed.
# Day 233 failed.
# Day 234 failed.
# Day 235 failed.
# Day 238 failed.
# Day 239 failed.
# Day 241 failed.
# Day 243 failed.
# Day 248 failed.
# Day 250 failed.
# Day 251 failed.
# Day 255 failed.
# Day 256 failed.
# Day 257 failed.
# Day 259 failed.
# Day 260 failed.
# Day 261 failed.
# Day 262 failed.
# Day 264 failed.
# Day 265 failed.
# Day 266 failed.
# Day 269 failed.
# Day 270 failed.
# Day 275 failed.
# Day 276 failed.
# Day 279 failed.
# Day 280 failed.
# Day 284 failed.
# Day 285 failed.
# Day 289 failed.
# Day 290 failed.
# Day 291 failed.
# Day 292 failed.
# Day 293 failed.
# Day 296 failed.
# Day 299 failed.
# Day 300 failed.
# Day 306 failed.
# Day 308 failed.
# Day 309 failed.
# Day 312 failed.
# Day 313 failed.
# Day 314 failed.
# Day 318 failed.
# Day 320 failed.
# Day 321 failed.
# Day 322 failed.
# Day 323 failed.
# Day 324 failed.
# Day 325 failed.
# Day 327 failed.
# Day 328 failed.
# Day 329 failed.
# Day 330 failed.
# Day 332 failed.
# Day 333 failed.
# Day 334 failed.
# Day 335 failed.
# Day 337 failed.
# Day 338 failed.
# Day 339 failed.
# Day 340 failed.
# Day 342 failed.
# Day 344 failed.
# Day 345 failed.
# Day 347 failed.
# Day 351 failed.
# Day 352 failed.
# Day 353 failed.
# Day 354 failed.
# Day 357 failed.
# Day 358 failed.
# Day 359 failed.
# Day 364 failed.
# Day 367 failed.
# Day 368 failed.
# Day 369 failed.
# Day 371 failed.
# Day 374 failed.
# Day 375 failed.
# Day 377 failed.
# Day 379 failed.
# Day 380 failed.
# Day 381 failed.
# Day 383 failed.
# Day 384 failed.
# Day 385 failed.
# Day 387 failed.
# Day 388 failed.
# Day 389 failed.
# Day 393 failed.
# Day 394 failed.
# Day 395 failed.
# Day 397 failed.
# Day 398 failed.
# Day 399 failed.
# Day 401 failed.
# Day 402 failed.
# Day 403 failed.
# Day 404 failed.
# Day 405 failed.
# Day 408 failed.
# Day 409 failed.
# Day 410 failed.
# Day 411 failed.
# Day 412 failed.
# Day 413 failed.
# Day 415 failed.
# Day 416 failed.
# Day 417 failed.
# Day 418 failed.
# Day 419 failed.
# Day 420 failed.
# Day 421 failed.
# Day 422 failed.
# Day 423 failed.
# Day 424 failed.
# Day 427 failed.
# Day 428 failed.
# Day 429 failed.
# Day 430 failed.
# Day 432 failed.
# Day 433 failed.
# Day 434 failed.
# Day 435 failed.
# Day 436 failed.
# Day 437 failed.
# Day 440 failed.
# Day 441 failed.
# Day 444 failed.
# Day 446 failed.
# Day 448 failed.
# Day 451 failed.
# Day 452 failed.
# Day 453 failed.
# Day 454 failed.
# Day 455 failed.
# Day 457 failed.
# Day 458 failed.
# Day 459 failed.
# Day 460 failed.
# Day 461 failed.
# Day 462 failed.
# Day 463 failed.
# Day 464 failed.
# Day 465 failed.
# Day 466 failed.
# Day 467 failed.
# Day 469 failed.
# Day 470 failed.
# Day 472 failed.
# Day 474 failed.
# Day 476 failed.
# Day 477 failed.
# Day 478 failed.
# Day 479 failed.
# Day 481 failed.
# Day 482 failed.
# Day 484 failed.
# Day 486 failed.
# Day 489 failed.
# Day 491 failed.
# Day 493 failed.
# Day 494 failed.
# Day 495 failed.
# Day 496 failed.
# Day 497 failed.
# Day 498 failed.
# Scenario 2 - Avg Cost: 501.88
# Day 0 failed.
# Day 1 failed.
# Day 3 failed.
# Day 6 failed.
# Day 7 failed.
# Day 8 failed.
# Day 11 failed.
# Day 12 failed.
# Day 15 failed.
# Day 18 failed.
# Day 20 failed.
# Day 21 failed.
# Day 23 failed.
# Day 25 failed.
# Day 26 failed.
# Day 27 failed.
# Day 28 failed.
# Day 30 failed.
# Day 32 failed.
# Day 34 failed.
# Day 35 failed.
# Day 36 failed.
# Day 40 failed.
# Day 41 failed.
# Day 43 failed.
# Day 44 failed.
# Day 45 failed.
# Day 46 failed.
# Day 47 failed.
# Day 48 failed.
# Day 49 failed.
# Day 52 failed.
# Day 53 failed.
# Day 55 failed.
# Day 57 failed.
# Day 58 failed.
# Day 59 failed.
# Day 64 failed.
# Day 67 failed.
# Day 68 failed.
# Day 69 failed.
# Day 70 failed.
# Day 71 failed.
# Day 72 failed.
# Day 75 failed.
# Day 77 failed.
# Day 79 failed.
# Day 80 failed.
# Day 81 failed.
# Day 82 failed.
# Day 83 failed.
# Day 84 failed.
# Day 85 failed.
# Day 86 failed.
# Day 87 failed.
# Day 89 failed.
# Day 91 failed.
# Day 92 failed.
# Day 94 failed.
# Day 96 failed.
# Day 97 failed.
# Day 98 failed.
# Day 99 failed.
# Day 102 failed.
# Day 103 failed.
# Day 105 failed.
# Day 107 failed.
# Day 108 failed.
# Day 109 failed.
# Day 112 failed.
# Day 114 failed.
# Day 115 failed.
# Day 116 failed.
# Day 118 failed.
# Day 119 failed.
# Day 120 failed.
# Day 121 failed.
# Day 122 failed.
# Day 123 failed.
# Day 124 failed.
# Day 125 failed.
# Day 127 failed.
# Day 128 failed.
# Day 129 failed.
# Day 131 failed.
# Day 132 failed.
# Day 133 failed.
# Day 136 failed.
# Day 140 failed.
# Day 141 failed.
# Day 143 failed.
# Day 145 failed.
# Day 148 failed.
# Day 149 failed.
# Day 150 failed.
# Day 151 failed.
# Day 154 failed.
# Day 155 failed.
# Day 157 failed.
# Day 158 failed.
# Day 159 failed.
# Day 161 failed.
# Day 164 failed.
# Day 166 failed.
# Day 167 failed.
# Day 168 failed.
# Day 169 failed.
# Day 170 failed.
# Day 174 failed.
# Day 177 failed.
# Day 178 failed.
# Day 179 failed.
# Day 180 failed.
# Day 183 failed.
# Day 185 failed.
# Day 186 failed.
# Day 188 failed.
# Day 189 failed.
# Day 191 failed.
# Day 192 failed.
# Day 195 failed.
# Day 196 failed.
# Day 199 failed.
# Day 200 failed.
# Day 201 failed.
# Day 202 failed.
# Day 203 failed.
# Day 205 failed.
# Day 206 failed.
# Day 207 failed.
# Day 209 failed.
# Day 212 failed.
# Day 213 failed.
# Day 214 failed.
# Day 215 failed.
# Day 216 failed.
# Day 217 failed.
# Day 218 failed.
# Day 219 failed.
# Day 220 failed.
# Day 221 failed.
# Day 222 failed.
# Day 223 failed.
# Day 225 failed.
# Day 226 failed.
# Day 227 failed.
# Day 228 failed.
# Day 229 failed.
# Day 233 failed.
# Day 234 failed.
# Day 235 failed.
# Day 238 failed.
# Day 239 failed.
# Day 241 failed.
# Day 243 failed.
# Day 248 failed.
# Day 250 failed.
# Day 251 failed.
# Day 255 failed.
# Day 256 failed.
# Day 257 failed.
# Day 259 failed.
# Day 260 failed.
# Day 261 failed.
# Day 262 failed.
# Day 264 failed.
# Day 265 failed.
# Day 266 failed.
# Day 269 failed.
# Day 270 failed.
# Day 275 failed.
# Day 276 failed.
# Day 279 failed.
# Day 280 failed.
# Day 284 failed.
# Day 285 failed.
# Day 289 failed.
# Day 290 failed.
# Day 291 failed.
# Day 292 failed.
# Day 293 failed.
# Day 296 failed.
# Day 299 failed.
# Day 300 failed.
# Day 306 failed.
# Day 308 failed.
# Day 309 failed.
# Day 312 failed.
# Day 313 failed.
# Day 314 failed.
# Day 318 failed.
# Day 320 failed.
# Day 321 failed.
# Day 322 failed.
# Day 323 failed.
# Day 324 failed.
# Day 325 failed.
# Day 327 failed.
# Day 328 failed.
# Day 329 failed.
# Day 330 failed.
# Day 332 failed.
# Day 333 failed.
# Day 334 failed.
# Day 335 failed.
# Day 337 failed.
# Day 338 failed.
# Day 339 failed.
# Day 340 failed.
# Day 342 failed.
# Day 344 failed.
# Day 345 failed.
# Day 347 failed.
# Day 351 failed.
# Day 352 failed.
# Day 353 failed.
# Day 354 failed.
# Day 357 failed.
# Day 358 failed.
# Day 359 failed.
# Day 364 failed.
# Day 367 failed.
# Day 368 failed.
# Day 369 failed.
# Day 371 failed.
# Day 374 failed.
# Day 375 failed.
# Day 377 failed.
# Day 379 failed.
# Day 380 failed.
# Day 381 failed.
# Day 383 failed.
# Day 384 failed.
# Day 385 failed.
# Day 387 failed.
# Day 388 failed.
# Day 389 failed.
# Day 393 failed.
# Day 394 failed.
# Day 395 failed.
# Day 397 failed.
# Day 398 failed.
# Day 399 failed.
# Day 401 failed.
# Day 402 failed.
# Day 403 failed.
# Day 404 failed.
# Day 405 failed.
# Day 408 failed.
# Day 409 failed.
# Day 410 failed.
# Day 411 failed.
# Day 412 failed.
# Day 413 failed.
# Day 415 failed.
# Day 416 failed.
# Day 417 failed.
# Day 418 failed.
# Day 419 failed.
# Day 420 failed.
# Day 421 failed.
# Day 422 failed.
# Day 423 failed.
# Day 424 failed.
# Day 427 failed.
# Day 428 failed.
# Day 429 failed.
# Day 430 failed.
# Day 432 failed.
# Day 433 failed.
# Day 434 failed.
# Day 435 failed.
# Day 436 failed.
# Day 437 failed.
# Day 440 failed.
# Day 441 failed.
# Day 444 failed.
# Day 446 failed.
# Day 448 failed.
# Day 451 failed.
# Day 452 failed.
# Day 453 failed.
# Day 454 failed.
# Day 455 failed.
# Day 457 failed.
# Day 458 failed.
# Day 459 failed.
# Day 460 failed.
# Day 461 failed.
# Day 462 failed.
# Day 463 failed.
# Day 464 failed.
# Day 465 failed.
# Day 466 failed.
# Day 467 failed.
# Day 469 failed.
# Day 470 failed.
# Day 472 failed.
# Day 474 failed.
# Day 476 failed.
# Day 477 failed.
# Day 478 failed.
# Day 479 failed.
# Day 481 failed.
# Day 482 failed.
# Day 484 failed.
# Day 486 failed.
# Day 489 failed.
# Day 491 failed.
# Day 493 failed.
# Day 494 failed.
# Day 495 failed.
# Day 496 failed.
# Day 497 failed.
# Day 498 failed.
# Day 0 failed.
# Day 1 failed.
# Day 3 failed.
# Day 6 failed.
# Day 7 failed.
# Day 8 failed.
# Day 11 failed.
# Day 12 failed.
# Day 15 failed.
# Day 18 failed.
# Day 20 failed.
# Day 21 failed.
# Day 23 failed.
# Day 25 failed.
# Day 26 failed.
# Day 27 failed.
# Day 28 failed.
# Day 30 failed.
# Day 32 failed.
# Day 34 failed.
# Day 35 failed.
# Day 36 failed.
# Day 40 failed.
# Day 41 failed.
# Day 43 failed.
# Day 44 failed.
# Day 45 failed.
# Day 46 failed.
# Day 47 failed.
# Day 48 failed.
# Day 49 failed.
# Day 52 failed.
# Day 53 failed.
# Day 55 failed.
# Day 57 failed.
# Day 58 failed.
# Day 59 failed.
# Day 64 failed.
# Day 67 failed.
# Day 68 failed.
# Day 69 failed.
# Day 70 failed.
# Day 71 failed.
# Day 72 failed.
# Day 75 failed.
# Day 77 failed.
# Day 79 failed.
# Day 80 failed.
# Day 81 failed.
# Day 82 failed.
# Day 83 failed.
# Day 84 failed.
# Day 85 failed.
# Day 86 failed.
# Day 87 failed.
# Day 89 failed.
# Day 91 failed.
# Day 92 failed.
# Day 94 failed.
# Day 96 failed.
# Day 97 failed.
# Day 98 failed.
# Day 99 failed.
# Day 102 failed.
# Day 103 failed.
# Day 105 failed.
# Day 107 failed.
# Day 108 failed.
# Day 109 failed.
# Day 112 failed.
# Day 114 failed.
# Day 115 failed.
# Day 116 failed.
# Day 118 failed.
# Day 119 failed.
# Day 120 failed.
# Day 121 failed.
# Day 122 failed.
# Day 123 failed.
# Day 124 failed.
# Day 125 failed.
# Day 127 failed.
# Day 128 failed.
# Day 129 failed.
# Day 131 failed.
# Day 132 failed.
# Day 133 failed.
# Day 136 failed.
# Day 140 failed.
# Day 141 failed.
# Day 143 failed.
# Day 145 failed.
# Day 148 failed.
# Day 149 failed.
# Day 150 failed.
# Day 151 failed.
# Day 154 failed.
# Day 155 failed.
# Day 157 failed.
# Day 158 failed.
# Day 159 failed.
# Day 161 failed.
# Day 164 failed.
# Day 166 failed.
# Day 167 failed.
# Day 168 failed.
# Day 169 failed.
# Day 170 failed.
# Day 174 failed.
# Day 177 failed.
# Day 178 failed.
# Day 179 failed.
# Day 180 failed.
# Day 183 failed.
# Day 185 failed.
# Day 186 failed.
# Day 188 failed.
# Day 189 failed.
# Day 191 failed.
# Day 192 failed.
# Day 195 failed.
# Day 196 failed.
# Day 199 failed.
# Day 200 failed.
# Day 201 failed.
# Day 202 failed.
# Day 203 failed.
# Day 205 failed.
# Day 206 failed.
# Day 207 failed.
# Day 209 failed.
# Day 212 failed.
# Day 213 failed.
# Day 214 failed.
# Day 215 failed.
# Day 216 failed.
# Day 217 failed.
# Day 218 failed.
# Day 219 failed.
# Day 220 failed.
# Day 221 failed.
# Day 222 failed.
# Day 223 failed.
# Day 225 failed.
# Day 226 failed.
# Day 227 failed.
# Day 228 failed.
# Day 229 failed.
# Day 233 failed.
# Day 234 failed.
# Day 235 failed.
# Day 238 failed.
# Day 239 failed.
# Day 241 failed.
# Day 243 failed.
# Day 248 failed.
# Day 250 failed.
# Day 251 failed.
# Day 255 failed.
# Day 256 failed.
# Day 257 failed.
# Day 259 failed.
# Day 260 failed.
# Day 261 failed.
# Day 262 failed.
# Day 264 failed.
# Day 265 failed.
# Day 266 failed.
# Day 269 failed.
# Day 270 failed.
# Day 275 failed.
# Day 276 failed.
# Day 279 failed.
# Day 280 failed.
# Day 284 failed.
# Day 285 failed.
# Day 289 failed.
# Day 290 failed.
# Day 291 failed.
# Day 292 failed.
# Day 293 failed.
# Day 296 failed.
# Day 299 failed.
# Day 300 failed.
# Day 306 failed.
# Day 308 failed.
# Day 309 failed.
# Day 312 failed.
# Day 313 failed.
# Day 314 failed.
# Day 318 failed.
# Day 320 failed.
# Day 321 failed.
# Day 322 failed.
# Day 323 failed.
# Day 324 failed.
# Day 325 failed.
# Day 327 failed.
# Day 328 failed.
# Day 329 failed.
# Day 330 failed.
# Day 332 failed.
# Day 333 failed.
# Day 334 failed.
# Day 335 failed.
# Day 337 failed.
# Day 338 failed.
# Day 339 failed.
# Day 340 failed.
# Day 342 failed.
# Day 344 failed.
# Day 345 failed.
# Day 347 failed.
# Day 351 failed.
# Day 352 failed.
# Day 353 failed.
# Day 354 failed.
# Day 357 failed.
# Day 358 failed.
# Day 359 failed.
# Day 364 failed.
# Day 367 failed.
# Day 368 failed.
# Day 369 failed.
# Day 371 failed.
# Day 374 failed.
# Day 375 failed.
# Day 377 failed.
# Day 379 failed.
# Day 380 failed.
# Day 381 failed.
# Day 383 failed.
# Day 384 failed.
# Day 385 failed.
# Day 387 failed.
# Day 388 failed.
# Day 389 failed.
# Day 393 failed.
# Day 394 failed.
# Day 395 failed.
# Day 397 failed.
# Day 398 failed.
# Day 399 failed.
# Day 401 failed.
# Day 402 failed.
# Day 403 failed.
# Day 404 failed.
# Day 405 failed.
# Day 408 failed.
# Day 409 failed.
# Day 410 failed.
# Day 411 failed.
# Day 412 failed.
# Day 413 failed.
# Day 415 failed.
# Day 416 failed.
# Day 417 failed.
# Day 418 failed.
# Day 419 failed.
# Day 420 failed.
# Day 421 failed.
# Day 422 failed.
# Day 423 failed.
# Day 424 failed.
# Day 427 failed.
# Day 428 failed.
# Day 429 failed.
# Day 430 failed.
# Day 432 failed.
# Day 433 failed.
# Day 434 failed.
# Day 435 failed.
# Day 436 failed.
# Day 437 failed.
# Day 440 failed.
# Day 441 failed.
# Day 444 failed.
# Day 446 failed.
# Day 448 failed.
# Day 451 failed.
# Day 452 failed.
# Day 453 failed.
# Day 454 failed.
# Day 455 failed.
# Day 457 failed.
# Day 458 failed.
# Day 459 failed.
# Day 460 failed.
# Day 461 failed.
# Day 462 failed.
# Day 463 failed.
# Day 464 failed.
# Day 465 failed.
# Day 466 failed.
# Day 467 failed.
# Day 469 failed.
# Day 470 failed.
# Day 472 failed.
# Day 474 failed.
# Day 476 failed.
# Day 477 failed.
# Day 478 failed.
# Day 479 failed.
# Day 481 failed.
# Day 482 failed.
# Day 484 failed.
# Day 486 failed.
# Day 489 failed.
# Day 491 failed.
# Day 493 failed.
# Day 494 failed.
# Day 495 failed.
# Day 496 failed.
# Day 497 failed.
# Day 498 failed.
# Scenario 3 - Avg Cost: 502.41
